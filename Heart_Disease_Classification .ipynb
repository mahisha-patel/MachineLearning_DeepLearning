# %% [markdown]
# ## IMPORTING LIBRARIES/DATASETS AND PERFORM EXPLORATORY DATA ANALYSIS

# %%
# import the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
# read the csv file 
cardio_df = pd.read_csv("/home/mahisha/MachineLearning/ML_AI_6Projects/Bonus 2/cardio_train.csv", sep=";")

# %%
cardio_df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
# Drop id
cardio_df = cardio_df.drop(columns = 'id')

# %%
# since the age is given in days, we convert it into years
cardio_df['age'] = cardio_df['age']/365

# %%
cardio_df.head()
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  50.391781       2     168    62.0    110     80            1     1      0
# 1  55.419178       1     156    85.0    140     90            3     1      0
# 2  51.663014       1     165    64.0    130     70            3     1      0
# 3  48.282192       2     169    82.0    150    100            1     1      0
# 4  47.873973       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
# checking the null values
cardio_df.isnull().sum()
# Out:
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
# Checking the dataframe information

cardio_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          70000 non-null  float64
#  1   gender       70000 non-null  int64
#  2   height       70000 non-null  int64
#  3   weight       70000 non-null  float64
#  4   ap_hi        70000 non-null  int64
#  5   ap_lo        70000 non-null  int64
#  6   cholesterol  70000 non-null  int64
#  7   gluc         70000 non-null  int64
#  8   smoke        70000 non-null  int64
#  9   alco         70000 non-null  int64
#  10  active       70000 non-null  int64
#  11  cardio       70000 non-null  int64
# dtypes: float64(2), int64(10)
# memory usage: 6.4 MB

# %%
# Statistical summary of the dataframe
cardio_df.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      53.339358      1.349571    164.359229     74.205690    128.817286
# std        6.759594      0.476838      8.210126     14.395757    154.011419
# min       29.583562      1.000000     55.000000     10.000000   -150.000000
# 25%       48.394521      1.000000    159.000000     65.000000    120.000000
# 50%       53.980822      1.000000    165.000000     72.000000    120.000000
# 75%       58.430137      2.000000    170.000000     82.000000    140.000000
# max       64.967123      2.000000    250.000000    200.000000  16020.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      96.630414      1.366871      1.226457      0.088129      0.053771
# std      188.472530      0.680250      0.572270      0.283484      0.225568
# min      -70.000000      1.000000      1.000000      0.000000      0.000000
# 25%       80.000000      1.000000      1.000000      0.000000      0.000000
# 50%       80.000000      1.000000      1.000000      0.000000      0.000000
# 75%       90.000000      2.000000      1.000000      0.000000      0.000000
# max    11000.000000      3.000000      3.000000      1.000000      1.000000
#
#              active        cardio
# count  70000.000000  70000.000000
# mean       0.803729      0.499700
# std        0.397179      0.500003
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      0.000000
# 75%        1.000000      1.000000
# max        1.000000      1.000000

# %%
cardio_df.hist(bins = 30, figsize = (20,20), color = 'r')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7b224a5eb0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b22407580>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b22433a00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7b223e1e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b22398310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b223426a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7b22342790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b223781f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b222c9100>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7b2227f820>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b222a8fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b2225d790>]],
#       dtype=object)

# %%
# get the correlation matrix
corr_matrix = cardio_df.corr()
corr_matrix

# plotting the correlation matrix
plt.figure(figsize = (16,16))
sns.heatmap(corr_matrix, annot = True)
plt.show()

# %%
sns.pairplot(cardio_df, hue = 'cardio')
# Out:
# /home/mahisha/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# /home/mahisha/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# /home/mahisha/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# /home/mahisha/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# /home/mahisha/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# /home/mahisha/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# /home/mahisha/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# /home/mahisha/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# /home/mahisha/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## BUILD AND TRAIN AN ARTIFICIAL NEURAL NETWORK MODEL

# %%
cardio_df.head()
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  50.391781       2     168    62.0    110     80            1     1      0
# 1  55.419178       1     156    85.0    140     90            3     1      0
# 2  51.663014       1     165    64.0    130     70            3     1      0
# 3  48.282192       2     169    82.0    150    100            1     1      0
# 4  47.873973       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
# split the dataframe into target and features

y = cardio_df['cardio']
X = cardio_df.drop(columns = ['cardio'])

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
X.shape
# Out:
# (70000, 11)

# %%
y.shape
# Out:
# (70000,)

# %%
#spliting the data in to test and train sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train.shape
# Out:
# (56000, 11)

# %%
y_train.shape
# Out:
# (56000,)

# %%
X_test.shape
# Out:
# (14000, 11)

# %%
y_test.shape
# Out:
# (14000,)

# %%
classifier = tf.keras.models.Sequential()
classifier.add(tf.keras.layers.Dense(units=400, activation='relu', input_shape=(11, )))
classifier.add(tf.keras.layers.Dropout(0.2))

classifier.add(tf.keras.layers.Dense(units=400, activation='relu'))
classifier.add(tf.keras.layers.Dense(units=400, activation='relu'))

classifier.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 400)               4800
# _________________________________________________________________
# dropout (Dropout)            (None, 400)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_2 (Dense)              (None, 400)               160400
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 401
# =================================================================
# Total params: 326,001
# Trainable params: 326,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier.compile(optimizer='Adam', loss='binary_crossentropy', metrics = ['accuracy'])

# %%
epochs_hist = classifier.fit(X_train, y_train, epochs = 20)
# Out:
# Epoch 1/20
# 1750/1750 [==============================] - 6s 3ms/step - loss: 0.5813 - accuracy: 0.7108
# Epoch 2/20
# 1750/1750 [==============================] - 6s 3ms/step - loss: 0.5528 - accuracy: 0.7294
# Epoch 3/20
# 1750/1750 [==============================] - 6s 3ms/step - loss: 0.5513 - accuracy: 0.7306
# Epoch 4/20
# 1750/1750 [==============================] - 6s 3ms/step - loss: 0.5462 - accuracy: 0.7335
# Epoch 5/20
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.5452 - accuracy: 0.7343
# Epoch 6/20
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.5437 - accuracy: 0.7334
# Epoch 7/20
# 1750/1750 [==============================] - 6s 3ms/step - loss: 0.5432 - accuracy: 0.7337
# Epoch 8/20
# 1750/1750 [==============================] - 7s 4ms/step - loss: 0.5430 - accuracy: 0.7352
# Epoch 9/20
# 1750/1750 [==============================] - 6s 3ms/step - loss: 0.5419 - accuracy: 0.7349
# Epoch 10/20
# 1750/1750 [==============================] - 6s 3ms/step - loss: 0.5411 - accuracy: 0.7367
# Epoch 11/20
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.5413 - accuracy: 0.7350
# Epoch 12/20
# 1750/1750 [==============================] - 6s 3ms/step - loss: 0.5404 - accuracy: 0.7364
# Epoch 13/20
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.5398 - accuracy: 0.7357
# Epoch 14/20
# 1750/1750 [==============================] - 6s 3ms/step - loss: 0.5389 - accuracy: 0.7363
# Epoch 15/20
# 1750/1750 [==============================] - 6s 4ms/step - loss: 0.5391 - accuracy: 0.7366
# Epoch 16/20
# 1750/1750 [==============================] - 6s 3ms/step - loss: 0.5385 - accuracy: 0.7371
# Epoch 17/20
# 1750/1750 [==============================] - 6s 3ms/step - loss: 0.5378 - accuracy: 0.7374
# Epoch 18/20
# 1750/1750 [==============================] - 6s 3ms/step - loss: 0.5379 - accuracy: 0.7382
# Epoch 19/20
# 1750/1750 [==============================] - 6s 3ms/step - loss: 0.5374 - accuracy: 0.7379
# Epoch 20/20
# 1750/1750 [==============================] - 6s 3ms/step - loss: 0.5368 - accuracy: 0.7378

# %%
y_pred = classifier.predict(X_test)

# %%
y_pred
# Out:
# array([[0.48926556],
#        [0.86946344],
#        [0.28716296],
#        ...,
#        [0.22992334],
#        [0.8281742 ],
#        [0.15756062]], dtype=float32)

# %%
y_pred = (y_pred > 0.5)

# %%
y_pred
# Out:
# array([[False],
#        [ True],
#        [False],
#        ...,
#        [False],
#        [ True],
#        [False]])

# %% [markdown]
# ## EVALUATE THE ARTIFICIAL NEURAL NETWORK MODEL

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'accuracy'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.legend(['Training Loss'])

# %%
plt.plot(epochs_hist.history['accuracy'])
plt.title('Model Accuracy Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training Accuracy')
plt.legend(['Training Accuracy'])

# %%
# Testing Set Performance
from sklearn.metrics import confusion_matrix, classification_report

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.78      0.74      6963
#            1       0.76      0.68      0.72      7037
#
#     accuracy                           0.73     14000
#    macro avg       0.73      0.73      0.73     14000
# weighted avg       0.73      0.73      0.73     14000

# %% [markdown]
# ## BUILD AND TRAIN AN XGBOOST CLASSIFIER MODEL

# %%
from xgboost import XGBClassifier

model = XGBClassifier()

model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
# make predictions on test data

predict = model.predict(X_test)

# %%
predict
# Out:
# array([0, 1, 0, ..., 0, 1, 0])

# %%
print(classification_report(y_test, predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.78      0.74      6963
#            1       0.76      0.68      0.72      7037
#
#     accuracy                           0.73     14000
#    macro avg       0.73      0.73      0.73     14000
# weighted avg       0.73      0.73      0.73     14000

# %%
# plot the confusion matrix

cm = confusion_matrix(y_test, predict)
plt.figure()
sns.heatmap(cm, annot=True)
